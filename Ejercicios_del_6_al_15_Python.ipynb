# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulandrea14/PROGCOM_B_2026/blob/main/Ejercicios_del_6_al_15_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6. Desarrolla un programa que determine si un número es par o impar.

# %%
num=float(input("Ingrese el número: "))
if num % 2==0:
  print("El número es par")
else:
  print("El número es impar")
# Out:
# Ingrese el número: 4
# El número es par

# %%
num=float(input("Ingrese el número: "))
"El número es par" if num % 2==0 else "El número es impar"
# Out:
# Ingrese el número: 5
# 'El número es impar'

# %% [markdown]
# 7. Crea un programa que determine si un año es bisiesto (divisible por 4 y no por 100, o divisible por 400).

# %%
año=float(input("Ingrese el año: "))
if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
  print("El año es bisiesto")
else:
  print("El año no es bisiesto")
# Out:
# Ingrese el año: 2026
# El año no es bisiesto

# %%
año=float(input("Ingrese el año: "))
print("El año es bisiesto" if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0) else "El año no es bisiesto")
# Out:
# Ingrese el año: 2025
# El año no es bisiesto

# %% [markdown]
# 8. Escribe un programa que solicite el nombre del usuario y determine si una persona pertenece a la tercera edad (70 años o más) y si se cumple la condición, imprima que se le da prioridad en la fila.

# %%
nombre=input("Escriba su nombre: ")
edad=float(input("Escriba su edad: "))
if edad > 70:
  print("Tiene prioridad en la fila")
else:
    print("No tiene prioridad en la fila")
# Out:
# Escriba su nombre: Paula
# Escriba su edad: 20
# No tiene prioridad en la fila

# %%
nombre=input("Escriba su nombre: ")
edad=float(input("Escriba su edad: "))
print("Tiene prioridad en la fila" if edad > 70 else "No tiene prioridad en la fila")
# Out:
# Escriba su nombre: Paula
# Escriba su edad: 21
# No tiene prioridad en la fila

# %% [markdown]
# 9. Desarrolla un programa que compare tres números y muestre el mayor.

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
if num1 >= num2 and num1 >= num3:
    mayor = num1
else:
  if num2 >= num1 and num2 >= num3:
    mayor = num2
  else:
    mayor = num3
print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 9
# Ingrese el segundo número: 10
# Ingrese el tercer número: 4
# El número mayor es: 10.0

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
if num1 >= num2 and num1 >= num3:
    mayor = num1
elif num2 >= num1 and num2 >= num3:
    mayor = num2
else:
    mayor = num3
print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 3
# Ingrese el segundo número: 2
# Ingrese el tercer número: 5
# El número mayor es: 5.0

# %%
num1 = float(input("Ingrese el primer número: "))
num2 = float(input("Ingrese el segundo número: "))
num3 = float(input("Ingrese el tercer número: "))
mayor = num1 if num1 >= num2 and num1 >= num3 else num2 if num2 >= num1 and num2 >= num3 else num3
print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 5
# Ingrese el segundo número: 8
# Ingrese el tercer número: 9
# El número mayor es: 9.0

# %% [markdown]
# 10. Crea un programa que determine si un triángulo es equilátero, isósceles o escaleno según sus lados.

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
else:
  if lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
  else:
      tipo="Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)
# Out:
# Ingrese el lado 1: 9
# Ingrese el lado 2: 8
# Ingrese el lado 3: 9
# El tipo de triángulo que se forma es:  Isósceles

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
else:
      tipo="Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)
# Out:
# Ingrese el lado 1: 9
# Ingrese el lado 2: 5
# Ingrese el lado 3: 3
# El tipo de triángulo que se forma es:  Escaleno

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
tipo="Equilatero" if lado1 == lado2 and lado2 == lado3 else "Isósceles" if lado1 == lado2 or lado1 == lado3 or lado2 == lado3 else "Escaleno"
print("El tipo de triángulo que se forma es: ",tipo)
# Out:
# Ingrese el lado 1: 3
# Ingrese el lado 2: 5
# Ingrese el lado 3: 5
# El tipo de triángulo que se forma es:  Isósceles

# %% [markdown]
# 11. Escribe un programa que calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad). Al final, el programa debe imprimir: el nombre del usuario, su categoría y una breve descripción de lo que debe hacer de acuerdo a su categoría.

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
if imc<18.5:
  categoría= "Bajo peso"
  descripción= "Debes comer más"
else:
  if imc>=18.5 and imc<=24.9:
    categoría= "Normal"
    descripción= "No necesitas hacer nada"
  else:
      if imc>=25 and imc<=29.9:
        categoría= "Sobrepeso"
        descripción= "Estás un poco pasad@ de peso, debes alimentarte mejor"
      else:
        if imc>=30:
          categoría= "Obesidad"
          descripción= "Tu peso es peligroso para tu salud, ve al médico"

print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)
# Out:
# Cuál es su nombre: Paula
# Cuánto pesas: 48
# Cuánto mides: 1.58
# Su nombre es:  Paula
# Su categoría es:  Normal
# No necesitas hacer nada

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
if imc<18.5:
  categoría= "Bajo peso"
  descripción= "Debes comer más"
elif imc>=18.5 and imc<=24.9:
    categoría= "Normal"
    descripción= "No necesitas hacer nada"
elif imc>=25 and imc<=29.9:
    categoría= "Sobrepeso"
    descripción= "Estás un poco pasad@ de peso, debes alimentarte mejor"
else:
  categoría= "Obesidad"
  descripción= "Tu peso es peligroso para tu salud, ve al médico"

print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)
# Out:
# ¿Cuál es su nombre?: Paula
# ¿Cuánto pesas?: 48
# ¿Cuánto mides?: 1.58
# Su nombre es:  Paula
# Su categoría es:  Normal
# Descripción:  No necesitas hacer nada

# %%
nombre=input("¿Cuál es su nombre?: ")
peso=float(input("¿Cuánto pesas?: "))
estatura=float(input("¿Cuánto mides?: "))
imc= peso/(estatura*estatura)
Categoría= "Bajo peso" if imc<18.5 else "Normal" if imc>=18.5 and imc<=24.9 else "Sobrepeso" if imc>=25 and imc<=29.9 else "Obesidad"
Descripcipción= "Debes comer más" if imc<18.5 else "No necesitas hacer nada" if imc>=18.5 and imc<=24.9 else "Estás un poco pasad@ de peso, debes alimentarte mejor" if imc>=25 and imc<=29.9 else "Tu peso es peligroso para tu salud, ve al médico"
print("Su nombre es: ",nombre)
print("Su categoría es: ",categoría)
print("Descripción: ",descripción)
# Out:
# ¿Cuál es su nombre?: Paula
# ¿Cuánto pesas?: 48
# ¿Cuánto mides?: 1.58
# Su nombre es:  Paula
# Su categoría es:  Normal
# Descripción:  No necesitas hacer nada

# %% [markdown]
# 12. Desarrolla un programa que simule una calculadora simple (+, -, *, /) con dos números.

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)")
if op == "+" :
  resultado=num1+num2
else:
    if op == "-" :
      resultado=num1-num2
    else:
        if op == "*" :
          resultado=num1*num2
        else:
          resultado=num1/num2
print("El resultado de la operación es: ",resultado)
# Out:
# Ingrese el primer número6
# Ingrese el segundo número3
# ¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)/
# El resultado de la operación es:  2.0

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)")
if op == "+" :
  resultado=num1+num2
elif op == "-" :
      resultado=num1-num2
elif op == "*" :
          resultado=num1*num2
else:
          resultado=num1/num2
print("El resultado de la operación es: ",resultado)
# Out:
# Ingrese el primer número8
# Ingrese el segundo número4
# ¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)+
# El resultado de la operación es:  12.0

# %%
num1=float(input("Ingrese el primer número"))
num2=float(input("Ingrese el segundo número"))
op=input("¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)")
resultado= num1+num2 if op == "+" else num1-num2 if op == "-" else num1*num2 if op == "*" else num1/num2
print("El resultado de la operación es: ",resultado)
# Out:
# Ingrese el primer número10
# Ingrese el segundo número2
# ¿Qué operación quiere realizar entre esos dos números? (+, -, *, /)/
# El resultado de la operación es:  5.0

# %% [markdown]
# 13. Crea un programa que determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).

# %%
nota=float(input("Ingrese la nota (0-100): "))
if nota>90:
  calificación= "A"
else:
  if nota > 80:
   calificación= "B"
  else:
    if nota>60:
     calificación= "C"
    else:
      if nota>40:
       calificación= "D"
      else:
        calificación= "F"
print("La calificación en letra es: ",calificación)
# Out:
# Ingrese la nota (0-100): 75
# La calificación en letra es:  C

# %%
nota=float(input("Ingrese la nota (0-100): "))
if nota>90:
  calificación= "A"
elif nota > 80:
   calificación= "B"
elif nota>60:
     calificación= "C"
elif nota>40:
       calificación= "D"
else:
        calificación= "F"
print("La calificación en letra es: ",calificación)
# Out:
# Ingrese la nota (0-100): 95
# La calificación en letra es:  A

# %%
nota=float(input("Ingrese la nota (0-100): "))
calificación = "A" if nota>90 else "B" if nota>80 else "C" if nota>60 else "D" if nota>40 else "F"
print("La calificación en letra es: ",calificación)
# Out:
# Ingrese la nota (0-100): 65
# La calificación en letra es:  C

# %% [markdown]
# 14. Escribe un programa que determine el día de la semana según un número (1-7).

# %%
día=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
if día == 1:
  d= "Domingo"
else:
  if día == 2:
    d="Lunes"
  else:
    if día == 3:
      d="Martes"
    else:
      if día == 4:
        d="Miércoles"
      else:
        if día == 5:
          d="Jueves"
        else:
          if día == 6:
            d="Viernes"
          else:
            d="Sábado"
print("El día de la semana que corresponde a ese número es: ",d)
# Out:
# Escriba un número del 1 al 7 para descubrir que día de la semana es: 5
# El día de la semana que corresponde a ese número es:  Jueves

# %%
día=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
if día == 1:
  d= "Domingo"
elif día == 2:
    d="Lunes"
elif día == 3:
      d="Martes"
elif día == 4:
        d="Miércoles"
elif día == 5:
          d="Jueves"
elif día == 6:
            d="Viernes"
else:
            d="Sábado"
print("El día de la semana que corresponde a ese número es: ",d)
# Out:
# Escriba un número del 1 al 7 para descubrir que día de la semana es: 7
# El día de la semana que corresponde a ese número es:  Sábado

# %%
día=int(input("Escriba un número del 1 al 7 para descubrir que día de la semana es: "))
d= "Domingo" if día == 1 else "Lunes" if día == 2 else "Martes" if día == 3 else "Miércoles" if día == 4 else "Jueves" if día == 5 else "Viernes" if día == 6 else "Sábado"
print("El día de la semana que corresponde a ese número es: ",d)
# Out:
# Escriba un número del 1 al 7 para descubrir que día de la semana es: 2
# El día de la semana que corresponde a ese número es:  Lunes

# %% [markdown]
# 15. Desarrolla un programa que valide si tres números pueden formar un triángulo y de qué tipo es.

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:

  if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
  else:
    if lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
    else:
      tipo="Escaleno"

    print("Sí pueden formar un triángulo")
    print("El tipo de triángulo que se forma es: ",tipo)

else:
  print("No se puede formar un triángulo")
# Out:
# Ingrese el lado 1: 4
# Ingrese el lado 2: 6
# Ingrese el lado 3: 4
# Sí pueden formar un triángulo
# El tipo de triángulo que se forma es:  Isósceles

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:

  if lado1 == lado2 and lado2 == lado3:
    tipo="Equilatero"
  elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
      tipo="Isósceles"
  else:
      tipo="Escaleno"

  print("Sí pueden formar un triángulo")
  print("El tipo de triángulo que se forma es: ",tipo)

else:
  print("No se puede formar un triángulo")
# Out:
# Ingrese el lado 1: 9
# Ingrese el lado 2: 9
# Ingrese el lado 3: 9
# Sí pueden formar un triángulo
# El tipo de triángulo que se forma es:  Equilatero

# %%
lado1=float(input("Ingrese el lado 1: "))
lado2=float(input("Ingrese el lado 2: "))
lado3=float(input("Ingrese el lado 3: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:
  tipo="Equilatero" if lado1 == lado2 and lado2 == lado3 else "Isósceles" if lado1 == lado2 or lado1 == lado3 or lado2 == lado3 else "Escaleno"
  print("Sí pueden formar un triángulo")
  print("El tipo de triángulo que se forma es: ",tipo)
else:
  print("No se puede formar un triángulo")
# Out:
# Ingrese el lado 1: 4
# Ingrese el lado 2: 3
# Ingrese el lado 3: 4
# Sí pueden formar un triángulo
# El tipo de triángulo que se forma es:  Isósceles
