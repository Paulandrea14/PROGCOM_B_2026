# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulandrea14/PROGCOM_B_2026/blob/main/Clase_0_Conociendo_Collab_prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Título de nivel 1
# ##Título de nivel 2
# ###Título de nivel 3
#
# hola, cómo estás? ❤️

# %% [markdown]
# #Saludando al mundo

# %%
print("Hola mundo😘")
# Out:
# Hola mundo😘

# %% [markdown]
# ##INPUT
# Input es una función que permite ingresar datos.
#
# Posee tres funciones
# 1. Lee: Se puede ingresar información
# 2. Almacena: Gurada la información en una variable (var)
# 3. Declara: Todos los datos almacenados los vuelve string
#
# Sintaxis
# ```
# var=input(Aquí va su impresión)
# ```
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversión de datos.
# Para ello, coloque el tipo de ddato que desea convertir, y encierre el tipo original de dato entre paréntesis.
#
# ```
# var=int(input()) #Aquí se va a transformar un dato de string a entero
# var2=float(input()) #Se transforma de string a decimal
# var3=bool(input()) #Se transforma de string a booleano
# ```

# %%
nombre=input("¿Cómo te llamas?")

# %%
nombre

# %%
edad=int(input("¿Cuántos años tienes?"))

# %%
edad

# %%
edad_compañero=int(input("Gabriela, ¿cuántos años tienes?"))

# %%
edad_compañero

# %%
edad+edad_compañero
